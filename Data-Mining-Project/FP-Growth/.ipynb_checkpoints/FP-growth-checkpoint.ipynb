# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_csv('PF-GROWTH1.csv', header=None)
select_col = [ 2, 3, 4, 5, 6,7]
dataset = data[select_col]
column_names = ['product1', 'product2', 'product3', 'product4', 'product5', 'product6']
dataset.columns = column_names
dataset = dataset.drop(0, axis=0)
dataset
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           product1          product2       product3       product4  \
# 1    bottled water            dishes         coffee      margarine
# 2           yogurt     bottled water         coffee         dishes
# 3           yogurt     bottled water         dishes          fruit
# 4    bottled water            yogurt  bottled water         coffee
# 5    bottled water     bottled water         dishes         coffee
# ..             ...               ...            ...            ...
# 129         coffee  other vegetables          fruit  bottled water
# 130         dishes      citrus fruit  bottled water         coffee
# ...

# %%
transactions = []
for sublist in dataset.values.tolist():
    clean_sublist = [item for item in sublist if not pd.isnull(item)]
    transactions.append(clean_sublist)

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       fruit   beef  berries  bottled water  brown bread  butter  butter milk  \
# 0     False  False    False           True        False   False        False
# 1     False  False    False           True        False   False        False
# 2      True  False    False           True        False   False        False
# 3      True  False    False           True        False   False        False
# 4     False  False    False           True        False   False        False
# ..      ...    ...      ...            ...          ...     ...          ...
# 128    True  False    False           True        False   False        False
# ...

# %%
frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)
frequent_itemsets
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                         itemsets
# 0   0.947761                  (bottled water)
# 1   0.649254                         (dishes)
# 2   0.552239                         (coffee)
# 3   0.552239                         (yogurt)
# 4   0.388060                         ( fruit)
# 5   0.201493                   (citrus fruit)
# 6   0.253731                     (whole milk)
# 7   0.201493               (other vegetables)
# 8   0.634328          (bottled water, dishes)
# 9   0.529851          (bottled water, coffee)
# 10  0.373134                 (dishes, coffee)
# 11  0.253731                 (yogurt, coffee)
# ...

# %%
# Generate association rules
association_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
result = association_rules[['antecedents', 'consequents']]
result
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                 antecedents              consequents
# 0           (bottled water)                 (dishes)
# 1                  (dishes)          (bottled water)
# 2           (bottled water)                 (coffee)
# 3                  (coffee)          (bottled water)
# 4                  (dishes)                 (coffee)
# 5                  (coffee)                 (dishes)
# 6   (bottled water, dishes)                 (coffee)
# 7   (bottled water, coffee)                 (dishes)
# 8          (dishes, coffee)          (bottled water)
# 9                  (dishes)  (bottled water, coffee)
# ...

# %%
# رسم رسم بياني للعناصر المتكررة
plt.figure(figsize=(10, 6))
plt.barh(range(len(frequent_itemsets)), frequent_itemsets.support, tick_label=frequent_itemsets.itemsets)
plt.xlabel('Support')
plt.ylabel('Itemsets')
plt.title('Frequent Itemsets')
plt.show()

# رسم رسم بياني لقواعد الارتباط
plt.figure(figsize=(10, 6))
plt.scatter(association_rules.support, association_rules.confidence)
plt.xlabel('min_support')
plt.ylabel('Confidence')
plt.title('Association Rules')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-789e8f8022da> in <module>
#       1 # رسم رسم بياني للعناصر المتكررة
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.barh(range(len(frequent_itemsets)), frequent_itemsets.min_support, tick_label=frequent_itemsets.itemsets)
#       4 plt.xlabel('Support')
#       5 plt.ylabel('Itemsets')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
# ...
